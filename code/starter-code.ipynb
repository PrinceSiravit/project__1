# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### : Why the government should abolish the ACT and SAT?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Selected Data
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
#
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
#
# The SAT dataset is showing statistics related to the SAT test for each state in the U.S. from years 2017, 2018, and 2019.The SAT is a standardized test widely used for college admissions in the United States. The SAT has four sections: Reading, Writing and Language, Math (no calculator), and Math (calculator allowed). These datasets take data from years 2017 to 2019.
#
# The ACT dataset is showing statistics related to the ACT test for each state in the U.S. from years 2017, 2018, and 2019. The ACT is a standardized test used for college admissions in the United States that covers four academic skill areas: English, mathematics, reading, and science reasoning. The main four ACT test sections are individually scored on a scale of 1–36, and a composite score is the rounded whole number average of the four sections.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Collegeboard and ACT originally created the `SAT/ACT` test to diversify students admitted into the Ivy League, but instead, it only admits middle and upper-class white students to the top colleges. Colleges should not require students to take the `ACT/SAT` to gain admission because the test cannot fully measure a student’s intelligence and college preparedness. These exams unfairly and inaccurately measure students’ intelligence and eligibility for college, students’ GPA, and grade can as well. Intelligence can vary in numerous areas, not just in school. CollegeBoard announced in January 2022 that they will move the SAT online and cut down the test from three hours to two hours long in 2024. However, these actions will not change anything, and the `SAT/ACT` will remain unfair.
#
# The `ACT/SAT` exhibits social inequality, favoring people who can afford to pay for preparation for the `SAT`, and hurting those that come from low-income families, not receive educational opportunities. SAT prep books and tutoring classes rack up a massive bill for students. Registering for the tests can prove costly; the `ACT` and `SAT` costs are 55 U.S dollar and 60 U.S.dollar  Various families can only pay for one while a handful cannot pay for either. Several students can afford to take the test more than two or three times to achieve a satisfactory score, but a handful of families can only pay for their child to take the exam once. If the child fails to achieve a satisfactory score, they ruin their chance to get admitted to the college of their choice.
#
# About 51 universities and colleges have dropped the `ACT/SAT` requirement for at least fall 2021 in recent months, according to a list by the National Center for Fair and Open Testing, or FairTest, a nonprofit organization working to end the misuse of standardized testing.
#
# They include Boston University, which announced it's going test-optional for students applying for the fall 2021 and spring 2022 semesters, and the University of California, which said all nine of the schools in its system would suspend the requirement for students applying for fall 2021.
#
# Harvard University extended its optional policy for the `SAT` and `ACT` exams for applicants through 2026 in an announcement Thursday.
#
# The Ivy League school in Cambridge, Massachusetts, previously announced in 2020 that standardized tests would be optional for a year due to the limited access to testing sites students faced. After, it extended the policy for another year, then again this week through 2026.
#
# All of the above illustrates the problem with the ACT&SAT test, so it's the source of the problem statement.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:

# %%
# Code:
def mean_cal(n): 
    return sum(n)/ len(n)

mean_cal([1,2,3,4])
# Out:
# 2.5

# %% [markdown]
# 2. Manually calculate standard deviation:

# %%
# Code:
def std_dev(n):
    avg = mean_cal(n)
    tem = [ (i - avg)**2 for i in n ]
    SD = ( sum(tem) / len(tem) )**0.5
    return SD

# %%
std_dev([12,14,15])
# Out:
# 1.247219128924647

# %% [markdown]
# 3. Data cleaning function:

# %%
# Code:
def flt_con(n):
    n = n.replace('%','')
    n = float(n)/100
    return n

# %%
flt_con('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2

# %% [markdown]
# ### Libraries

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import

# %%
# Code:
# Act data from 2017-2019
df_act_2017 = pd.read_csv('../data/act_2017.csv') #2017 ACT Scores by State
df_act_2018 = pd.read_csv('../data/act_2018.csv') #2018 ACT Scores by State
df_act_2019 = pd.read_csv('../data/act_2019.csv') #2019 ACT Scores by State

# Sat data from 2017-2019
df_sat_2017 = pd.read_csv('../data/sat_2017.csv') #2017 SAT Scores by State
df_sat_2018 = pd.read_csv('../data/sat_2018.csv') #2018 SAT Scores by State
df_sat_2019 = pd.read_csv('../data/sat_2019.csv') #2019 SAT Scores by State

#ACT and SAT free testing state in U.S.
df_a_s_free = pd.read_csv('../data/act_sat_free.csv')

# %% [markdown]
# #### ACT

# %%
# Display 5 rows of ACT 2017
print('ACT 2017')
print(df_act_2017.head())
print('\n')
print('ACT 2018')
print(df_act_2018.head())
print('\n')
print('ACT 2019')
print(df_act_2019.head())
# Out:
# ACT 2017
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
#
#
# ACT 2018
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#
#
# ACT 2019
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %% [markdown]
# #### SAT

# %%
# Display 5 rows of ACT 2018
print('SAT 2017')
print (df_sat_2017.head())
print('\n')
print('SAT 2018')
print (df_sat_2018.head())
print('\n')
print('SAT 2019')
print (df_sat_2019.head())
# Out:
# SAT 2017
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#
#
# SAT 2018
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
#
#
# SAT 2019
# ...

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### Check for missing values

# %% [markdown]
# #### ACT

# %%
#Finding null value of each dataframe
print('ACT 2017')
print (df_act_2017.isnull().sum())

print('\n')
print('ACT 2018')
print (df_act_2018.isnull().sum())

print('\n')
print('ACT 2019')
print (df_act_2019.isnull().sum())
# Out:
# ACT 2017
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64
#
#
# ACT 2018
# State            0
# Participation    0
# Composite        0
# dtype: int64
#
#
# ACT 2019
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %% [markdown]
# #### SAT

# %%
#Finding null value of each dataframe
print('SAT 2017')
print (df_sat_2017.isnull().sum())

print('\n')
print('SAT 2018')
print (df_sat_2018.isnull().sum())

print('\n')
print('SAT 2019')
print (df_sat_2019.isnull().sum())
# Out:
# SAT 2017
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
#
# SAT 2018
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
#
# SAT 2019
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# ##### Result:
#
# From checking the missing value in every columns of each dataframe, it showed that the dataframe of ACT from 2017-2029 and SAT from 2017-2019 havn't any missing values.

# %% [markdown]
# #### Check for any obvious issues with the observations

# %% [markdown]
# ##### Checking Column and Outlier

# %% [markdown]
# #### ACT

# %%
#Checking Column and Outlier
print('ACT 2017')
print (df_act_2017.describe())

print('\n')
print('ACT 2018')
print (df_act_2018.describe())

print('\n')
print('ACT 2019')
print (df_act_2019.describe())
# Out:
# ACT 2017
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000
#
#
# ACT 2018
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000
#
#
# ACT 2019
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
#Checking Column and Outlier
print('SAT 2017')
print (df_sat_2017.describe())

print('\n')
print('SAT 2018')
print (df_sat_2018.describe())

print('\n')
print('SAT 2019')
print (df_sat_2019.describe())
# Out:
# SAT 2017
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000
#
#
# SAT 2018
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# ...

# %% [markdown]
# ##### Result:
# After checking for any issues, the result showed that the `Participation Rate` columns of SAT 2017-2019 and ACT 2017-2019 can't be described because of it still being string, the `Accepted Rate` column of SAT and ACT data of each university in USA too. Moreover, the `Composite` column of SAT 2017 didn't show also.
#
# For the described data, it showed the columns `Science` of SAT 2017 has outlier in minimun value. Moreover, the count of ACT and SAT 2017-2019 is not equal so it need to be adjused.

# %% [markdown]
# ### Fix error

# %% [markdown]
# ### ACT

# %% [markdown]
# ##### 1. The `Composite` column of ACT 2017 is string because it has an "x" in the last rows. Thus, the columns need to be removed x and changed the type to be float.

# %%
#Check types
df_act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
#Display the error row
df_act_2017.tail(5)
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
#Replace x by space
df_act_2017['Composite'] = df_act_2017['Composite'].str.replace('x','')

# %%
#Check the result
df_act_2017.tail(5)
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %%
#Change type of column to be float
df_act_2017['Composite'] = df_act_2017['Composite'].astype(float)

# %% [markdown]
# Checking for correction of `Composite` and `Total` columns of SAT 2017 and ACT 2017-2019

# %%
#Check for the result
df_act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# ##### 2. The rows of ACT 2017-2019 is not equaled. After checking, i found the national rows which need to be removed to fit with all dataframe and the duplicated rows in ACT 2018 which need to be removed too.

# %%
df_act_2017 = df_act_2017.drop(df_act_2017.index[0])

# %%
df_act_2018 = df_act_2018.drop(df_act_2018.index[20])

# %%
df_act_2019 = df_act_2019.drop(df_act_2019.index[51])

# %% [markdown]
# #### Check the rows of ACT

# %%
print (df_act_2017.shape)
print (df_act_2018.shape)
print (df_act_2019.shape)
# Out:
# (51, 7)
# (51, 3)
# (51, 3)

# %% [markdown]
# ### SAT

# %% [markdown]
# ##### 1. The oultlier of SAT2017 is in the un-used column, it will be drop one next step.

# %% [markdown]
# ##### 2. Puerto Rico and Virgin Islands rows will be droped because it is not in the same pattern with other SAT years.

# %%
#Drop un-used rows
df_sat_2019 = df_sat_2019.drop(df_sat_2019.index[[39,47]])

# %% [markdown]
# ##### Swap two rows of sat 2018

# %%
#Swap two rows 
df_sat_2018.iloc[35:37] = np.flip(df_sat_2018.to_numpy()[35:37], axis=0)

# %% [markdown]
# #### Check the rows of SAT

# %%
#Check the number of rows
print (df_sat_2017.shape)
print (df_sat_2018.shape)
print (df_sat_2019.shape)
# Out:
# (51, 5)
# (51, 5)
# (51, 5)

# %% [markdown]
# #### Display the data types of each feature.

# %%
#Check the data types
print('ACT 2017')
print(df_act_2017.dtypes)

print('\n')
print('ACT 2018')
print(df_act_2018.dtypes)

print('\n')
print('ACT 2019')
print(df_act_2019.dtypes)
# Out:
# ACT 2017
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object
#
#
# ACT 2018
# State             object
# Participation     object
# Composite        float64
# dtype: object
#
#
# ACT 2019
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
#Check the data types
print('SAT 2017')
print(df_sat_2017.dtypes)

print('\n')
print('SAT 2018')
print(df_sat_2018.dtypes)

print('\n')
print('SAT 2019')
print(df_sat_2019.dtypes)
# Out:
# SAT 2017
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# SAT 2018
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# SAT 2019
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %% [markdown]
# #### Fix incorrect data types

# %%
# Remove the % and change data in the column to be float.

# %%
df_act_2017['Participation'] = df_act_2017['Participation'].apply(flt_con)

# %%
df_act_2018['Participation'] = df_act_2018['Participation'].apply(flt_con)

# %%
df_act_2019['Participation'] = df_act_2019['Participation'].apply(flt_con)

# %%
#Check for the result
print('ACT 2017')
print(df_act_2017.dtypes)

print('\n')
print('ACT 2018')
print(df_act_2018.dtypes)

print('\n')
print('ACT 2019')
print(df_act_2019.dtypes)
# Out:
# ACT 2017
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object
#
#
# ACT 2018
# State             object
# Participation    float64
# Composite        float64
# dtype: object
#
#
# ACT 2019
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
# Remove the % and change data in the column to be float.

# %%
df_sat_2017['Participation'] = df_sat_2017['Participation'].apply(flt_con)

# %%
df_sat_2018['Participation'] = df_sat_2018['Participation'].apply(flt_con)

# %%
df_sat_2019['Participation Rate'] = df_sat_2019['Participation Rate'].apply(flt_con)

# %%
print('SAT 2017')
print(df_sat_2017.dtypes)

print('\n')
print('SAT 2018')
print(df_sat_2018.dtypes)

print('\n')
print('SAT 2019')
print(df_sat_2019.dtypes)
# Out:
# SAT 2017
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
#
# SAT 2018
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
#
# SAT 2019
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %% [markdown]
# #### Result
#
# Every `Participation` columns of every dataframe are deleted % and become float

# %% [markdown]
# #### Rename Columns

# %% [markdown]
# ##### 1. Rename columns

# %% [markdown]
# ### ACT

# %%
# Rename columns
df_act_2017.rename(columns={'State':'state','Participation':'participation_act_2017',
                            'Composite':'total_score_act_2017'}, inplace = True)
df_act_2018.rename(columns={'State':'state','Participation':'participation_act_2018',
                            'Composite':'total_score_act_2018'}, inplace = True)
df_act_2019.rename(columns={'State':'state','Participation':'participation_act_2019',
                            'Composite':'total_score_act_2019'}, inplace = True)

# %%
#Check the result
print(df_act_2017.columns)
print(df_act_2018.columns)
print(df_act_2019.columns)
# Out:
# Index(['state', 'participation_act_2017', 'English', 'Math', 'Reading',
#        'Science', 'total_score_act_2017'],
#       dtype='object')
# Index(['state', 'participation_act_2018', 'total_score_act_2018'], dtype='object')
# Index(['state', 'participation_act_2019', 'total_score_act_2019'], dtype='object')

# %% [markdown]
# ### SAT

# %%
# Rename columns
df_sat_2017.rename(columns={'State':'state','Participation':'participation_sat_2017',
                            'Total':'total_score_sat_2017'},inplace = True)
df_sat_2018.rename(columns={'State':'state','Participation':'participation_sat_2018',
                            'Total':'total_score_sat_2018'},inplace = True)
df_sat_2019.rename(columns={'State':'state','Participation Rate':'participation_sat_2019',
                            'Total':'total_score_sat_2019'}, inplace = True)

# %%
#Check the result
print(df_sat_2017.columns)
print(df_sat_2018.columns)
print(df_sat_2019.columns)
# Out:
# Index(['state', 'participation_sat_2017', 'Evidence-Based Reading and Writing',
#        'Math', 'total_score_sat_2017'],
#       dtype='object')
# Index(['state', 'participation_sat_2018', 'Evidence-Based Reading and Writing',
#        'Math', 'total_score_sat_2018'],
#       dtype='object')
# Index(['state', 'participation_sat_2019', 'EBRW', 'Math',
#        'total_score_sat_2019'],
#       dtype='object')

# %% [markdown]
# ### Drop unnecessary columns

# %% [markdown]
# ### ACT

# %%
#Drop columns
df_act_2017.drop(['English', 'Math', 'Reading', 'Science'], axis=1, inplace = True)

# %%
#Check columns
print(df_act_2017.columns)
print(df_act_2018.columns)
print(df_act_2019.columns)
# Out:
# Index(['state', 'participation_act_2017', 'total_score_act_2017'], dtype='object')
# Index(['state', 'participation_act_2018', 'total_score_act_2018'], dtype='object')
# Index(['state', 'participation_act_2019', 'total_score_act_2019'], dtype='object')

# %% [markdown]
# ### SAT

# %%
#Drop columns
df_sat_2017.drop(columns=['Evidence-Based Reading and Writing', 'Math'],axis = 1, inplace = True)
df_sat_2018.drop(columns=['Evidence-Based Reading and Writing', 'Math'],axis = 1, inplace = True)
df_sat_2019.drop(columns=['EBRW', 'Math'],axis = 1, inplace = True)

# %%
#Check columns
print(df_sat_2017.columns)
print(df_sat_2018.columns)
print(df_sat_2019.columns)
# Out:
# Index(['state', 'participation_sat_2017', 'total_score_sat_2017'], dtype='object')
# Index(['state', 'participation_sat_2018', 'total_score_sat_2018'], dtype='object')
# Index(['state', 'participation_sat_2019', 'total_score_sat_2019'], dtype='object')

# %% [markdown]
# ### Merge dataframes

# %% [markdown]
# ### ACT

# %%
#Reset index before merge

# %%
df_act_2017.reset_index(drop=True, inplace=True)

# %%
df_act_2018.reset_index(drop=True, inplace=True)

# %%
df_act_2019.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##### Merge ACT 2017-2019 and SAT 2017-2019

# %%
#Merge column of ACT 2017-2019

# %%
df_act_all = pd.merge(df_act_2017, df_act_2018, how='left',left_index=True,  right_index=True,  
                      suffixes=('df_act_2017', 'df_act_2018'))

# %%
df_act_all = pd.merge(df_act_all, df_act_2019, how='left',left_index=True,  right_index=True,  
                      suffixes=('df_act_all', 'df_act_2019'))

# %%
#Check the result
df_act_all.head()
# Out:
#   statedf_act_2017  participation_act_2017  total_score_act_2017  \
# 0          Alabama                    1.00                  19.2
# 1           Alaska                    0.65                  19.8
# 2          Arizona                    0.62                  19.7
# 3         Arkansas                    1.00                  19.4
# 4       California                    0.31                  22.8
#
#   statedf_act_2018  participation_act_2018  total_score_act_2018       state  \
# 0          Alabama                    1.00                  19.1     Alabama
# 1           Alaska                    0.33                  20.8      Alaska
# 2          Arizona                    0.66                  19.2     Arizona
# 3         Arkansas                    1.00                  19.4    Arkansas
# 4       California                    0.27                  22.7  California
#
#    participation_act_2019  total_score_act_2019
# 0                    1.00                  18.9
# ...

# %% [markdown]
# ### SAT

# %%
#Reset index before merge

# %%
df_sat_2017.reset_index(drop=True, inplace=True)

# %%
df_sat_2018.reset_index(drop=True, inplace=True)

# %%
df_sat_2019.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Merge

# %%
#Merge data

# %%
df_sat_all = pd.merge(df_sat_2017, df_sat_2018, how='left',left_index=True,  right_index=True,  
                      suffixes=('df_sat_2017', 'df_sat_2018'))

# %%
df_sat_all = pd.merge(df_sat_all, df_sat_2019, how='left',left_index=True,  right_index=True,  
                      suffixes=('df_sat_all', 'df_sat_2019'))

# %%
#Check for the result
df_sat_all.head()
# Out:
#   statedf_sat_2017  participation_sat_2017  total_score_sat_2017  \
# 0          Alabama                    0.05                  1165
# 1           Alaska                    0.38                  1080
# 2          Arizona                    0.30                  1116
# 3         Arkansas                    0.03                  1208
# 4       California                    0.53                  1055
#
#   statedf_sat_2018  participation_sat_2018  total_score_sat_2018       state  \
# 0          Alabama                    0.06                  1166     Alabama
# 1           Alaska                    0.43                  1106      Alaska
# 2          Arizona                    0.29                  1149     Arizona
# 3         Arkansas                    0.05                  1169    Arkansas
# 4       California                    0.60                  1076  California
#
#    participation_sat_2019  total_score_sat_2019
# 0                    0.07                  1143
# ...

# %% [markdown]
# ### Arrange the data

# %%
# Drop the duplicated columns of ACT and SAT

# %%
df_act_all.drop(['statedf_act_2018','state'], axis =1, inplace = True)

# %%
df_sat_all.drop(['statedf_sat_2018','state'], axis =1, inplace = True)

# %%
df_act_all.rename(columns={'statedf_act_2017':'state'}, inplace = True)

# %%
df_sat_all.rename(columns={'statedf_sat_2017':'state'}, inplace = True)

# %%
#Check for the result
df_act_all.head()
# Out:
#         state  participation_act_2017  total_score_act_2017  \
# 0     Alabama                    1.00                  19.2
# 1      Alaska                    0.65                  19.8
# 2     Arizona                    0.62                  19.7
# 3    Arkansas                    1.00                  19.4
# 4  California                    0.31                  22.8
#
#    participation_act_2018  total_score_act_2018  participation_act_2019  \
# 0                    1.00                  19.1                    1.00
# 1                    0.33                  20.8                    0.38
# 2                    0.66                  19.2                    0.73
# 3                    1.00                  19.4                    1.00
# 4                    0.27                  22.7                    0.23
#
#    total_score_act_2019
# 0                  18.9
# 1                  20.1
# 2                  19.0
# 3                  19.3
# 4                  22.6

# %%
#Check for the result
df_sat_all.head()
# Out:
#         state  participation_sat_2017  total_score_sat_2017  \
# 0     Alabama                    0.05                  1165
# 1      Alaska                    0.38                  1080
# 2     Arizona                    0.30                  1116
# 3    Arkansas                    0.03                  1208
# 4  California                    0.53                  1055
#
#    participation_sat_2018  total_score_sat_2018  participation_sat_2019  \
# 0                    0.06                  1166                    0.07
# 1                    0.43                  1106                    0.41
# 2                    0.29                  1149                    0.31
# 3                    0.05                  1169                    0.06
# 4                    0.60                  1076                    0.63
#
#    total_score_sat_2019
# 0                  1143
# 1                  1097
# 2                  1134
# 3                  1141
# 4                  1065

# %% [markdown]
# ### Merge Data ACT and SAT

# %%
df_all = pd.merge(df_act_all, df_sat_all, how='left',left_index=True,  right_index=True,  
                      suffixes=('df_act_all', 'df_sat_all'))

# %%
df_all.head()
# Out:
#   statedf_act_all  participation_act_2017  total_score_act_2017  \
# 0         Alabama                    1.00                  19.2
# 1          Alaska                    0.65                  19.8
# 2         Arizona                    0.62                  19.7
# 3        Arkansas                    1.00                  19.4
# 4      California                    0.31                  22.8
#
#    participation_act_2018  total_score_act_2018  participation_act_2019  \
# 0                    1.00                  19.1                    1.00
# 1                    0.33                  20.8                    0.38
# 2                    0.66                  19.2                    0.73
# 3                    1.00                  19.4                    1.00
# 4                    0.27                  22.7                    0.23
#
#    total_score_act_2019 statedf_sat_all  participation_sat_2017  \
# 0                  18.9         Alabama                    0.05
# ...

# %% [markdown]
# ### Drop state and rename column

# %%
df_all.drop(['statedf_sat_all'], axis =1, inplace = True)

# %%
df_all.rename(columns={'statedf_act_all':'state'}, inplace = True)

# %%
df_all.head()
# Out:
#         state  participation_act_2017  total_score_act_2017  \
# 0     Alabama                    1.00                  19.2
# 1      Alaska                    0.65                  19.8
# 2     Arizona                    0.62                  19.7
# 3    Arkansas                    1.00                  19.4
# 4  California                    0.31                  22.8
#
#    participation_act_2018  total_score_act_2018  participation_act_2019  \
# 0                    1.00                  19.1                    1.00
# 1                    0.33                  20.8                    0.38
# 2                    0.66                  19.2                    0.73
# 3                    1.00                  19.4                    1.00
# 4                    0.27                  22.7                    0.23
#
#    total_score_act_2019  participation_sat_2017  total_score_sat_2017  \
# 0                  18.9                    0.05                  1165
# ...

# %% [markdown]
# ### Add U.S. state offer the ACT or SAT for free columns

# %%
df_a_s_free.head()
# Out:
#         state  act_free  sat_free
# 0     Alabama         1         0
# 1      Alaska         0         0
# 2     Arizona         1         0
# 3    Arkansas         0         0
# 4  California         0         0

# %%
df_all = pd.merge(df_all, df_a_s_free, how='left',left_index=True,  right_index=True,  
                      suffixes=('df_act_all', 'df_a_s_free'))

# %%
df_all.head()
# Out:
#   statedf_act_all  participation_act_2017  total_score_act_2017  \
# 0         Alabama                    1.00                  19.2
# 1          Alaska                    0.65                  19.8
# 2         Arizona                    0.62                  19.7
# 3        Arkansas                    1.00                  19.4
# 4      California                    0.31                  22.8
#
#    participation_act_2018  total_score_act_2018  participation_act_2019  \
# 0                    1.00                  19.1                    1.00
# 1                    0.33                  20.8                    0.38
# 2                    0.66                  19.2                    0.73
# 3                    1.00                  19.4                    1.00
# 4                    0.27                  22.7                    0.23
#
#    total_score_act_2019  participation_sat_2017  total_score_sat_2017  \
# 0                  18.9                    0.05                  1165
# ...

# %%
df_all.drop(['statedf_a_s_free'], axis =1, inplace = True)

# %%
df_all.rename(columns={'statedf_act_all':'state'}, inplace = True)

# %%
df_all.head()
# Out:
#         state  participation_act_2017  total_score_act_2017  \
# 0     Alabama                    1.00                  19.2
# 1      Alaska                    0.65                  19.8
# 2     Arizona                    0.62                  19.7
# 3    Arkansas                    1.00                  19.4
# 4  California                    0.31                  22.8
#
#    participation_act_2018  total_score_act_2018  participation_act_2019  \
# 0                    1.00                  19.1                    1.00
# 1                    0.33                  20.8                    0.38
# 2                    0.66                  19.2                    0.73
# 3                    1.00                  19.4                    1.00
# 4                    0.27                  22.7                    0.23
#
#    total_score_act_2019  participation_sat_2017  total_score_sat_2017  \
# 0                  18.9                    0.05                  1165
# ...

# %% [markdown]
# ### Save Dataframe

# %%
#Save the dataframe to be csv files.

# %%
df_act_all.to_csv('../data/df_act_all.csv')

# %%
df_sat_all.to_csv('../data/df_sat_all.csv')

# %%
df_all.to_csv('../data/df_all.csv')

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|object|df_act_all|U.S. state
# |**participation_act_2017**|float|df_all| ACT's participation rate in each state in U.S. 2017.
# |**total_score_act_2017**|float|df_all| ACT's total average score in each state in U.S. 2017.
# |**participation_act_2018**|float|df_all| ACT's participation rate in each state in U.S. 2018.
# |**total_score_act_2018**|float|df_all| ACT's total average score in each state in U.S. 2018.
# |**participation_act_2019**|float|df_all| ACT's participation rate in each state in U.S. 2019.
# |**total_score_act_2019**|float|df_all| ACT's total average score in each state in U.S. 2019.
# |**participation_sat_2017**|float|df_all| SAT's participation rate in each state in U.S. 2017.
# |**total_score_sat_2017**|integer|df_all| SAT's total average score in each state in U.S. 2017.
# |**participation_sat_2018**|float|df_all| SAT's participation rate in each state in U.S. 2018.
# |**total_score_sat_2018**|integer|df_all| SAT's total average score in each state in U.S. 2018.
# |**participation_sat_2019**|float|df_all| SAT's participation rate in each state in U.S. 2019.
# |**total_score_sat_2019**|integer|df_all| SAT's total average score in each state in U.S. 2019.
# |**act_free**|boolean|df_all| State Offer the ACT for Free.
# |**sat_free**|boolean|df_all| State Offer the SAT for Free.

# %%
#Display the columns
df_all.head()
# Out:
#         state  participation_act_2017  total_score_act_2017  \
# 0     Alabama                    1.00                  19.2
# 1      Alaska                    0.65                  19.8
# 2     Arizona                    0.62                  19.7
# 3    Arkansas                    1.00                  19.4
# 4  California                    0.31                  22.8
#
#    participation_act_2018  total_score_act_2018  participation_act_2019  \
# 0                    1.00                  19.1                    1.00
# 1                    0.33                  20.8                    0.38
# 2                    0.66                  19.2                    0.73
# 3                    1.00                  19.4                    1.00
# 4                    0.27                  22.7                    0.23
#
#    total_score_act_2019  participation_sat_2017  total_score_sat_2017  \
# 0                  18.9                    0.05                  1165
# ...

# %%
#Display types of each column
df_all.dtypes
# Out:
# state                      object
# participation_act_2017    float64
# total_score_act_2017      float64
# participation_act_2018    float64
# total_score_act_2018      float64
# participation_act_2019    float64
# total_score_act_2019      float64
# participation_sat_2017    float64
# total_score_sat_2017        int64
# participation_sat_2018    float64
# total_score_sat_2018        int64
# participation_sat_2019    float64
# total_score_sat_2019        int64
# act_free                    int64
# sat_free                    int64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Summary Statistics

# %%
#Explore the statistics of ACT data
df_all.describe().T
# Out:
#                         count         mean        std     min       25%  \
# participation_act_2017   51.0     0.652549   0.321408    0.08     0.310
# total_score_act_2017     51.0    21.519608   2.020695   17.80    19.800
# participation_act_2018   51.0     0.617255   0.340371    0.07     0.285
# total_score_act_2018     51.0    21.496078   2.111583   17.70    19.950
# participation_act_2019   51.0     0.586667   0.345159    0.06     0.245
# total_score_act_2019     51.0    21.464706   2.194523   17.90    19.800
# participation_sat_2017   51.0     0.398039   0.352766    0.02     0.040
# total_score_sat_2017     51.0  1126.098039  92.494812  950.00  1055.500
# participation_sat_2018   51.0     0.457451   0.373143    0.02     0.045
# total_score_sat_2018     51.0  1120.019608  94.155083  977.00  1057.500
# participation_sat_2019   51.0     0.490588   0.387476    0.02     0.055
# total_score_sat_2019     51.0  1113.078431  97.197910  943.00  1038.000
# ...

# %% [markdown]
# #### SD's Data dictionary

# %%
#Display the standard deviation of each column
columns = list(df_all.columns)
stdv = { key:std_dev( df_all[key] ) for key in columns[1:] }
stdv
# Out:
# {'participation_act_2017': 0.3182417575123181,
#  'total_score_act_2017': 2.000786081581989,
#  'participation_act_2018': 0.33701735820410317,
#  'total_score_act_2018': 2.090779082141178,
#  'participation_act_2019': 0.3417582373703047,
#  'total_score_act_2019': 2.172901153595978,
#  'participation_sat_2017': 0.3492907076664507,
#  'total_score_sat_2017': 91.58351056778743,
#  'participation_sat_2018': 0.3694661922353942,
#  'total_score_sat_2018': 93.22742384464433,
#  'participation_sat_2019': 0.3836584048685726,
#  'total_score_sat_2019': 96.24027185617864,
#  'act_free': 0.4882313567838719,
#  'sat_free': 0.46400625749800906}

# %% [markdown]
# ### Investigate trends in the data.

# %% [markdown]
# #### The average of selected column

# %%
print (df_all[['participation_act_2017','participation_act_2018','participation_act_2019']].mean())

print (df_all[['participation_sat_2017','participation_sat_2018','participation_sat_2019']].mean())
# Out:
# participation_act_2017    0.652549
# participation_act_2018    0.617255
# participation_act_2019    0.586667
# dtype: float64
# participation_sat_2017    0.398039
# participation_sat_2018    0.457451
# participation_sat_2019    0.490588
# dtype: float64

# %% [markdown]
# From the result, it show that the average of participation rate of ACT is decreased but the SAT is incresed.

# %%
print(df_all[['total_score_act_2017','total_score_act_2018','total_score_act_2019']].mean())


print(df_all[['total_score_sat_2017','total_score_sat_2018','total_score_sat_2019']].mean())
# Out:
# total_score_act_2017    21.519608
# total_score_act_2018    21.496078
# total_score_act_2019    21.464706
# dtype: float64
# total_score_sat_2017    1126.098039
# total_score_sat_2018    1120.019608
# total_score_sat_2019    1113.078431
# dtype: float64

# %% [markdown]
# From the result, it show that the total score of ACT and SAT are decreased every year.

# %% [markdown]
# #### From the result of participation and total score average each year trend, it can be explained:
#
# Although participation is increased or decreased, total score of both test also decreased.

# %% [markdown]
# ## Visualize the Data

# %% [markdown]
# ### 1. Seaborn's Heatmap

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation SAT&ACT participation rate and core VS U.S. state which offer free tests')
mask = np.triu(df_all.corr())
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df_all.corr(), annot=True, cmap= 'magma', mask=mask, vmin=-1, vmax=1);

# %%
fig, ax = plt.subplots(ncols=2, figsize=(15,10))
plt.subplots_adjust(wspace=0.4)
sns.heatmap(df_all.corr()[['act_free']].sort_values('act_free', ascending=False),
            annot=True, cmap='Spectral', ax=ax[0], vmin=-1, vmax=1).set_title('Correlation SAT&ACT participation rate and core VS U.S. state which offer free ACT');
sns.heatmap(df_all.corr()[['sat_free']].sort_values('sat_free', ascending=False),
            annot=True, cmap='Spectral', ax=ax[1], vmin=-1, vmax=1).set_title('Correlation SAT&ACT participation rate and core VS U.S. state which offer free SAT');

# %% [markdown]
# #### From the heatmap, it can be explained insights follow this:
# 1. Participation has a has negative relationship with the test score.
# 2. The offer of state for free testing has a negative relationship with the test score but have positive relationship with participation rate.
# 3. ACT may have higher relationship with its participation than SAT

# %% [markdown]
# ### 2. Scatter plots

# %%
plt.style.use('seaborn');
fig, ax = plt.subplots(ncols= 2, nrows=2 ,figsize=(15,10))
sns.regplot(x =df_all['total_score_act_2018'], y =df_all['participation_act_2018'], color = 'r', ax= ax[0,0]).set_title("ACT's Participation Rate vs Score 2018");
ax[0,0].axvline(df_all['total_score_act_2018'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1)
ax[0,0].axhline(df_all['participation_act_2018'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1);

sns.regplot(x =df_all['total_score_act_2019'], y =df_all['participation_act_2019'], color = 'r', ax= ax[0,1]).set_title("ACT's Participation Rate vs Score 2019");
ax[0,1].axvline(df_all['total_score_act_2019'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1)
ax[0,1].axhline(df_all['participation_act_2019'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1);

sns.regplot(x =df_all['total_score_sat_2018'], y =df_all['participation_sat_2018'], color = 'r', ax= ax[1,0]).set_title("SAT's Participation Rate vs Score 2018");
ax[1,0].axvline(df_all['total_score_sat_2018'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1)
ax[1,0].axhline(df_all['participation_sat_2018'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1);

sns.regplot(x =df_all['total_score_sat_2019'], y =df_all['participation_sat_2019'], color = 'r', ax= ax[1,1]).set_title("SAT's Participation Rate vs Score 2019");
ax[1,1].axvline(df_all['total_score_sat_2019'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1)
ax[1,1].axhline(df_all['participation_sat_2019'].mean(), color='k', alpha=0.5, linestyle='--', linewidth=1);

# %% [markdown]
# #### From fourth scatter plot:
#
# It shows clearly about the negative relationship between participation and total score of both ACT and SAT.

# %% [markdown]
# ### 3. Line Chart

# %%
Year1 = [2017,2018,2019]
avg_score_act1 = [21.519,21.496,21.464]
Year1 = pd.to_datetime(Year1, format='%Y')
  
plt.plot(Year1, avg_score_act1, color = 'r',marker = 'o')
plt.title("ACT's Average Score Vs Year",fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.ylabel("ACT's Average Score ",fontsize=14)
plt.show()

Year2 = [2017,2018,2019]
avg_score_sat2 = [1126.098,1120.019,1113.078]
Year2 = pd.to_datetime(Year2, format='%Y')
  
plt.plot(Year2, avg_score_sat2, color= 'r',marker = 'o')
plt.title("SAT's Average Score Vs Year",fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.ylabel("SAT's Average Score ",fontsize=14)
plt.show()

# %%
Year1 = [2017,2018,2019]
par_rate_act1 = [0.65,0.61,0.58]
Year1 = pd.to_datetime(Year1, format='%Y')
  
plt.plot(Year1, par_rate_act1 , color= 'r',marker = 'o')
plt.title("ACT's Participation Rate Vs Year", fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel("ACT's Participation Rate ", fontsize=14)
plt.show()

Year2 = [2017,2018,2019]
par_rate_sat2 = [0.39,0.45,0.49]
Year2 = pd.to_datetime(Year2, format='%Y')

plt.plot(Year2, par_rate_sat2 , color = 'b', marker = 'o')
plt.title("SAT's Participation Rate Vs Year", fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel("SAT's Participation Rate ", fontsize=14)
plt.show()

# %% [markdown]
# #### From line chart, it can be explained follow this:
# 1. ACT and SAT average score has a positive relationship. They have the same trends.
# 2. ACT and SAT participation rate has a negative relationship. While ACT participation rate decease, SAT's participation rate is increased.

# %% [markdown]
# #### For participation rate of SAT can explain follow this
#
# SAT vs ACT: Some Key Differences may answer why SAT participation has a negative relationship with ACT
#
# 1. The SAT gives you more time per question than the ACT does.
# 2. While the ACT contains a section entirely devoted to science, the SAT does not.
# 3. The SAT contains a Math "No Calculator" subsection for which you may not use a calculator.
# 4. while ACT Math gives you five possible answer choices (A-E or F-K) for each question, SAT Math only gives you four (A-D).

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusions

# %% [markdown]
# From the testing result, it shows that ACT and SAT participation rate and total score have a negative relationship and free testing offer is a factor to motivate the ACT and SAT participation.
#
# Thus, it can explain like this. If the free testing offer is increased, it make average total score decreased and participated is increased.
#
# Although the participation rate is increased, the way to get a free offering still have many condition to be a fee waiver which is not suitable for low income family. ([*source*](https://blog.prepscholar.com/sat-fee-waiver-complete-guide))
#
# Thus, The ACT&SAT exhibits social inequality, favoring people who can afford to pay for preparation for the SAT, and hurting those that come from low-income families, not receive educational opportunities.
#
# Opportunities may not come to the right person, in the right place, and at the right time.

# %% [markdown]
# ## Recommendations

# %% [markdown]
# ![Screen%20Shot%202565-09-07%20at%2013.29.13.png](attachment:Screen%20Shot%202565-09-07%20at%2013.29.13.png)

# %% [markdown]
# ##### For the government,
# From this picture, un-supported states for given ACT and SAT for free still have 19 states. It means inequlity. Although, some state support it but doesn't mean no condition for applying. Thus, the government should ebolish ACT&SAT which lead to solve inequality in society. Moreover, the government should find a way to promote students who need to join in university equally.
#
#
# ##### For colleges,
#
# They should focus on students’ grades, GPA, essays, extracurriculars and recommendations to determine one’s eligibility to enter college. People take the SAT/ACT from all kinds of backgrounds; certain students with high GPAs and grades do not achieve a strong score, destroying their chances to apply to a school of their choice. SAT/ACT should not hinder students from entering college. They prevent them from earning scholarships and entering the college of their dreams.

# %% [markdown]
# ---

# %% [markdown]
# ## Reference

# %% [markdown]
# https://theolivebook.com/states-that-offer-the-act-or-sat-for-free/
#
# https://nchschant.com/21994/opinions/why-the-government-should-abolish-the-sat-act/
#
# https://www.newsweek.com/harvard-drops-sat-act-exam-requirement-applicants-through-2026-1660756
#
# https://www.princetonreview.com/college/sat-sections
#
# https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html
#
# https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/
#
# https://edition.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html
#
# https://satsuite.collegeboard.org/sat
#
# https://www.act.org/content/act/en.html
#
# https://blog.prepscholar.com/sat-fee-waiver-complete-guide
