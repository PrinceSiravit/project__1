# %%
import pandas as pd

# %%
df_act_2017 = pd.read_csv('../data/act_2017.csv')
df_act_2018 = pd.read_csv('../data/act_2018.csv')
df_act_2019 = pd.read_csv('../data/act_2019.csv')

# %%
df_act_2017.head(100)
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
df_act_2017.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# dtype: bool

# %%
df_act_2018.head(100)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
df_act_2018.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# dtype: bool

# %%
df_act_2019.head(100)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %%
df_act_2019.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# dtype: bool

# %%
df_sat_2017 = pd.read_csv('../data/sat_2017.csv')
df_sat_2018 = pd.read_csv('../data/sat_2018.csv')
df_sat_2019 = pd.read_csv('../data/sat_2019.csv')

# %%
df_sat_2017.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# dtype: bool

# %%
df_sat_2018.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# dtype: bool

# %%
df_sat_2019.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# dtype: bool

# %%
df_sat_2017.head(100)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
df_sat_2018.head(100)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
df_sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
df_sat_2017.head(100)

# %%
import re

if df_sat_2019['Participation Rate']

# %%
import string
alphabet = string.ascii_letters+string.punctuation

# %%
df_sat_2017.'Participation Rate'.str.strip(alphabet).astype(bool).any()
# Out:
#   Input In [28]
#     df_sat_2017.'Participation Rate'.str.strip(alphabet).astype(bool).any()
#                 ^
# SyntaxError: invalid syntax

# %%
df_s_a_col = pd.read_csv('../data/sat_act_by_college.csv')

# %%
def check_all(n):
    
    al_list = ['']
    
    if n is str :
        n = n.replace(float)
        return 
    elif n is str and

# %%
df_act_2017['Composite'].
# Out:
# <bound method Series.items of 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2
# 10     19.8
# 11     21.4
# 12     19.0
# 13     22.3
# 14     21.4
# 15     22.6
# 16     21.9
# 17     21.7
# 18     20.0
# 19     19.5
# 20     24.3
# 21     23.6
# 22     25.4
# 23     24.1
# 24     21.5
# 25     18.6
# 26     20.4
# 27     20.3
# 28     21.4
# 29     17.8
# 30     25.5
# 31     23.9
# 32     19.7
# 33     24.2
# 34     19.1
# 35     20.3
# 36     22.0
# 37     19.4
# 38     21.8
# 39     23.7
# 40     24.0
# 41     18.7
# 42     21.8
# 43     19.8
# 44     20.7
# 45     20.3
# 46     23.6
# 47     23.8
# 48     21.9
# 49     20.4
# 50     20.5
# 51    20.2x
# Name: Composite, dtype: object>

# %%
df_act_2017["Composite"].str.replace("x","")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df_act_2017["Composite"].str.replace("x","", inplace = True)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# TypeError: replace() got an unexpected keyword argument 'inplace'

# %%
df_act_2017['Composite'] = df_act_2017["Composite"].str.replace("x","")

# %%
df_act_2017.dtypes =
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
df_act_2017['Composite'] = df_act_2017["Composite"]..replace("x","")

# %%
df_act_2017['Composite'] = df_act_2017['Composite'].astype(float)

# %%
df_act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
df_act_2017['avg'] = df_act_2017[['English','Math','Reading','Reading']].mean(axis=1)

# %%
df_act_2017.head(100)
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
df_sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_sat_2017['sum'] = df_sat_2017[['Evidence-Based Reading and Writing','Math']].sum(axis=1)

# %%
df_sat_2017.head(100)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
df_sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
df_sat_2018['avg'] = df_sat_2018[['Evidence-Based Reading and Writing','Math']].sum(axis =1)

# %%
df_sat_2018.head(100)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
df_sat_2018.dtypes
# Out:
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# avg                                   float64
# dtype: object

# %%
df_act_2017.head(100)
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
df_act_2017 = df_act_2017.drop(df_act_2017.index[0])

# %%
df_act_2017.head()
# Out:
#         State Participation  English  Math  Reading  Science  Composite  \
# 1     Alabama          100%     18.9  18.4     19.7     19.4       19.2
# 2      Alaska           65%     18.7  19.8     20.4     19.9       19.8
# 3     Arizona           62%     18.6  19.8     20.1     19.8       19.7
# 4    Arkansas          100%     18.9  19.0     19.7     19.5       19.4
# 5  California           31%     22.5  22.7     23.1     22.2       22.8
#
#       avg
# 1  19.175
# 2  19.825
# 3  19.650
# 4  19.325
# 5  22.850

# %%
df_act_2018.head(100)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
df_act_2018 = df_act_2018.drop_duplicates()

# %%
df_act_2018.head(100)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
df_act_2019.head(100)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %%
df_act_2019 = df_act_2019.drop(df_act_2019.index[51])

# %%
df_act_2019.head(100)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %%
df_sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# sat_2017 has outlier.

# %%
df_sat_2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
df_sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %%
It has missing valiable on participation rate columns.

# %%
data = data.drop(data.index[[1, 9, 29]])

# %%
df_sat_2019 = df_sat_2019.drop(df_sat_2019.index[[39,47]])

# %%
df_sat_2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %%
df_sat_2019.shape
# Out:
# (51, 5)

# %%
df_act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite', 'avg'],
#       dtype='object')

# %%
df_act_2017.rename(columns={'State':'state','Participation':'participation','Composite':'composite'})
# Out:
#                    state participation  English  Math  Reading  Science  \
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# 12                Hawaii           90%     17.8  19.2     19.2     19.3
# ...

# %%
df_act_2018.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
df_act_2018.rename(columns={'State':'state','Participation':'participation','Composite':'composite'})
# Out:
#                    state participation  composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
df_act_2019.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
df_act_2019.rename(columns={'State':'state','Participation':'participation','Composite':'composite'})
# Out:
#                    state participation  composite
# 0                Alabama          100%       18.9
# 1                 Alaska           38%       20.1
# 2                Arizona           73%       19.0
# 3               Arkansas          100%       19.3
# 4             California           23%       22.6
# 5               Colorado           27%       23.8
# 6            Connecticut           22%       25.5
# 7               Delaware           13%       24.1
# 8   District of Columbia           32%       23.5
# 9                Florida           54%       20.1
# 10               Georgia           49%       21.4
# 11                Hawaii           80%       19.0
# 12                 Idaho           31%       22.5
# 13              Illinois           35%       24.3
# 14               Indiana           29%       22.5
# 15                  Iowa           66%       21.6
# 16                Kansas           72%       21.2
# 17              Kentucky          100%       19.8
# ...

# %%
df_sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total', 'sum'],
#       dtype='object')

# %%
df_sat_2017.rename(columns={'State':'state','Participation':'participation','Total':'total_score'},inplace = True)
# Out:
#                    state participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
df_sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total', 'avg'],
#       dtype='object')

# %%
df_sat_2018.rename(columns={'State':'state','Participation':'participation','Total':'total_score'},inplace = True)
# Out:
#                    state participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
df_sat_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
df_sat_2019.rename(columns={'State':'state','Participation Rate':'participation','Total':'total_score'}, inplace = True)

# %%
df_act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite', 'avg'],
#       dtype='object')

# %%
df_act_2017.drop(columns =['English', 'Math', 'Reading', 'Science'], inplace = True)

# %%
df_act_2017.columns
# Out:
# Index(['State', 'Participation', 'Composite', 'avg'], dtype='object')

# %%
df_act_2019.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
df_sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total', 'sum'],
#       dtype='object')

# %%
df_sat_2017.drop(columns=['Evidence-Based Reading and Writing', 'Math'],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 df_sat_2017.drop(columns=['Evidence-Based Reading and Writing', 'Math'],inplace = True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
df_sat_2018.columns
# Out:
# Index(['state', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'total_score', 'avg'],
#       dtype='object')

# %%
df_sat_2018 = df_sat_2018.drop(columns=['Evidence-Based Reading and Writing', 'Math'],inplace = True)

# %%
df_sat_2019.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
df_sat_2019 = df_sat_2019.drop(columns=['EBRW', 'Math'],inplace = True)

# %%
df_act_2017.reset_index()
# Out:
#     index                 State Participation Composite
# 0       0              National           60%      21.0
# 1       1               Alabama          100%      19.2
# 2       2                Alaska           65%      19.8
# 3       3               Arizona           62%      19.7
# 4       4              Arkansas          100%      19.4
# 5       5            California           31%      22.8
# 6       6              Colorado          100%      20.8
# 7       7           Connecticut           31%      25.2
# 8       8              Delaware           18%      24.1
# 9       9  District of Columbia           32%      24.2
# 10     10               Florida           73%      19.8
# 11     11               Georgia           55%      21.4
# 12     12                Hawaii           90%      19.0
# 13     13                 Idaho           38%      22.3
# 14     14              Illinois           93%      21.4
# 15     15               Indiana           35%      22.6
# ...

# %%
df_act_2017 = pd.merge(df_act_2017, df_act_2018, how='left', 
                       left_index=True,  right_index=True,  suffixes=('df_act_2017', 
                                                                      'df_act_2018'))

# %%
df_act_2017 = pd.merge(df_act_2017, df_act_2019, how='left', 
                       left_index=True,  right_index=True,  suffixes=('df_act_2017', 
                                                                      'df_act_2019'))

# %%
df_act_2017
# Out:
#         Statedf_act_2017 Participationdf_act_2017 Compositedf_act_2017  \
# 0               National                      60%                 21.0
# 1                Alabama                     100%                 19.2
# 2                 Alaska                      65%                 19.8
# 3                Arizona                      62%                 19.7
# 4               Arkansas                     100%                 19.4
# 5             California                      31%                 22.8
# 6               Colorado                     100%                 20.8
# 7            Connecticut                      31%                 25.2
# 8               Delaware                      18%                 24.1
# 9   District of Columbia                      32%                 24.2
# 10               Florida                      73%                 19.8
# 11               Georgia                      55%                 21.4
# ...
